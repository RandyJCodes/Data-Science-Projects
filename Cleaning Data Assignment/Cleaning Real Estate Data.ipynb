# %%
import pandas as pd

# %%
data = pd.read_csv('realestate.csv', low_memory=False)

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data.dtypes #This will show us that the houseAge data is Float type
# Out:
# No                               int64
# transaction                    float64
# houseAge                       float64
# distanceToNearestMRTstation    float64
# numberOfConvenienceStores        int64
# latitude                       float64
# longitude                      float64
# housePriceOfUnitArea           float64
# dtype: object

# %%
data.houseAge.mean()
# Out:
# 17.62033492822966

# %%
data.houseAge
# Out:
# 0      32.0
# 1      19.5
# 2      13.3
# 3      13.3
# 4       5.0
#        ...
# 413    13.7
# 414     5.6
# 415    18.8
# 416     8.1
# 417     6.5
# Name: houseAge, Length: 418, dtype: float64

# %%
data.houseAge.min()
# Out:
# 0.0

# %%
data.houseAge.max()
# Out:
# 43.8

# %%
data.houseAge.std()
# Out:
# 11.428348063298536

# %%
houseAge = data.houseAge

# %%
norm = (houseAge - houseAge.mean()) / houseAge.std() #Standardized equation
norm
# Out:
# 0      1.258245
# 1      0.164474
# 2     -0.378037
# 3     -0.378037
# 4     -1.104301
#          ...
# 413   -0.343036
# 414   -1.051800
# 415    0.103223
# 416   -0.833046
# 417   -0.973048
# Name: houseAge, Length: 418, dtype: float64

# %%
minmax = (houseAge - houseAge.min()) / (houseAge.max() - houseAge.min()) #Normalizes all the data to be between 0 and 1

# %%
minmax.min() #Confirms that the lowest value is 0
# Out:
# 0.0

# %%
minmax.max() #Confirms that the highest value is 1
# Out:
# 1.0

# %%
minmax
# Out:
# 0      0.730594
# 1      0.445205
# 2      0.303653
# 3      0.303653
# 4      0.114155
#          ...
# 413    0.312785
# 414    0.127854
# 415    0.429224
# 416    0.184932
# 417    0.148402
# Name: houseAge, Length: 418, dtype: float64

# %%
data['houseAgeStandardized'] = minmax #Appends the normalized data to the dataset.

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  \
# 0      1     2012.917      32.0                     84.87882
# 1      2     2012.917      19.5                    306.59470
# 2      3     2013.583      13.3                    561.98450
# 3      4     2013.500      13.3                    561.98450
# 4      5     2012.833       5.0                    390.56840
# ..   ...          ...       ...                          ...
# 413  410     2013.000      13.7                   4082.01500
# 414  411     2012.667       5.6                     90.45606
# 415  412     2013.250      18.8                    390.96960
# 416  413     2013.000       8.1                    104.81010
# 417  414     2013.500       6.5                     90.45606
#
#      numberOfConvenienceStores  latitude  longitude  housePriceOfUnitArea  \
# 0                           10  24.98298  121.54024                   NaN
# 1                            9  24.98034  121.53951                  42.2
# ...

# %%
data.drop(columns=['numberOfConvenienceStores'])
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.drop(columns=['numberOfConvenienceStores'],inplace=True) #Permanently drops the convenience stores from the data set

# %%
data
# Out:
#       No  transaction  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1     2012.917      32.0                     84.87882  24.98298
# 1      2     2012.917      19.5                    306.59470  24.98034
# 2      3     2013.583      13.3                    561.98450  24.98746
# 3      4     2013.500      13.3                    561.98450  24.98746
# 4      5     2012.833       5.0                    390.56840  24.97937
# ..   ...          ...       ...                          ...       ...
# 413  410     2013.000      13.7                   4082.01500  24.94155
# 414  411     2012.667       5.6                     90.45606  24.97433
# 415  412     2013.250      18.8                    390.96960  24.97923
# 416  413     2013.000       8.1                    104.81010  24.96674
# 417  414     2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.rename({"transaction" : "transactionDate"}, axis=1) #Must mention axis 1 since axis 1 is the column axis.
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.rename({"transaction" : "transactionDate"}, axis=1, inplace=True) #Permanently makes the change to the column name

# %%
data
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.loc[0:10, :] #Loc is inclusive of the last number. This will display the rows 0-10
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 1    2         2012.917      19.5                    306.59470  24.98034
# 2    3         2013.583      13.3                    561.98450  24.98746
# 3    4         2013.500      13.3                    561.98450  24.98746
# 4    5         2012.833       5.0                    390.56840  24.97937
# 5    6         2012.667       7.1                   2175.03000  24.96305
# 6    7         2012.667      34.5                    623.47310  24.97933
# 7    8         2013.417      20.3                    287.60250  24.98042
# 8    9         2013.500      31.7                   5512.03800  24.95095
# 9   10         2013.417      17.9                   1783.18000  24.96731
# 10  11         2013.083      34.8                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.iloc[0:11, :] #iloc is exclusive of the last number. This will also display rows 0-10
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 1    2         2012.917      19.5                    306.59470  24.98034
# 2    3         2013.583      13.3                    561.98450  24.98746
# 3    4         2013.500      13.3                    561.98450  24.98746
# 4    5         2012.833       5.0                    390.56840  24.97937
# 5    6         2012.667       7.1                   2175.03000  24.96305
# 6    7         2012.667      34.5                    623.47310  24.97933
# 7    8         2013.417      20.3                    287.60250  24.98042
# 8    9         2013.500      31.7                   5512.03800  24.95095
# 9   10         2013.417      17.9                   1783.18000  24.96731
# 10  11         2013.083      34.8                    405.21340  24.97349
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
data.loc[data.duplicated()] #This locates all data that is duplicate.
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 211  211         2013.500       5.2                     390.5684  24.97937
# 234  217         2013.250      37.8                     590.9292  24.97153
# 277  254         2012.667      30.4                    1735.5950  24.96464
# 302  299         2013.333      16.7                    4082.0150  24.94155
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# 211  121.54245                  52.2              0.118721
# 234  121.53559                  39.7              0.863014
# 277  121.51623                  25.9              0.694064
# 302  121.50381                  16.7              0.381279

# %%
data.drop_duplicates(inplace=True) #This function will delete all duplicated data. The 4 rows shown in the previous function have been dropped

# %%
data #The original data set had 418 rows and now we have 414
# Out:
#       No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0      1         2012.917      32.0                     84.87882  24.98298
# 1      2         2012.917      19.5                    306.59470  24.98034
# 2      3         2013.583      13.3                    561.98450  24.98746
# 3      4         2013.500      13.3                    561.98450  24.98746
# 4      5         2012.833       5.0                    390.56840  24.97937
# ..   ...              ...       ...                          ...       ...
# 413  410         2013.000      13.7                   4082.01500  24.94155
# 414  411         2012.667       5.6                     90.45606  24.97433
# 415  412         2013.250      18.8                    390.96960  24.97923
# 416  413         2013.000       8.1                    104.81010  24.96674
# 417  414         2013.500       6.5                     90.45606  24.97433
#
#      longitude  housePriceOfUnitArea  houseAgeStandardized
# ...

# %%
from numpy import nan

# %%
data[data.isnull().any(axis=1)] #This will display all rows that contain a NaN value
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 27  28         2013.250      10.4                    276.44900  24.95593
# 37  38         2013.167      12.0                   1360.13900  24.95204
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# 0   121.54024                   NaN              0.730594
# 27  121.53913                   NaN              0.237443
# 37  121.54842                   NaN              0.273973

# %%
mean = data.housePriceOfUnitArea.mean() #For this project, we are replacing all NaN values with their column's mean.
mean
# Out:
# 38.07664233576642

# %%
data.fillna(value={'housePriceOfUnitArea': mean}, inplace=True) #This will take all NaN values in housePriceOfUnitArea and replace it with the mean data

# %%
data.iloc[[0, 27, 37], :] #Using iloc, we will display the rows that once had NaN values. We can confirm that 
#housePriceOfUnitArea in those rows have been replaced successfully with the mean for the column.
# Out:
#     No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0    1         2012.917      32.0                     84.87882  24.98298
# 27  28         2013.250      10.4                    276.44900  24.95593
# 37  38         2013.167      12.0                   1360.13900  24.95204
#
#     longitude  housePriceOfUnitArea  houseAgeStandardized
# 0   121.54024             38.076642              0.730594
# 27  121.53913             38.076642              0.237443
# 37  121.54842             38.076642              0.273973

# %%
data.head()
# Out:
#    No  transactionDate  houseAge  distanceToNearestMRTstation  latitude  \
# 0   1         2012.917      32.0                     84.87882  24.98298
# 1   2         2012.917      19.5                    306.59470  24.98034
# 2   3         2013.583      13.3                    561.98450  24.98746
# 3   4         2013.500      13.3                    561.98450  24.98746
# 4   5         2012.833       5.0                    390.56840  24.97937
#
#    longitude  housePriceOfUnitArea  houseAgeStandardized
# 0  121.54024             38.076642              0.730594
# 1  121.53951             42.200000              0.445205
# 2  121.54391             47.300000              0.303653
# 3  121.54391             54.800000              0.303653
# 4  121.54245             43.100000              0.114155
